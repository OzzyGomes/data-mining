# %% [markdown]
# <a href="https://colab.research.google.com/github/OzzyGomes/data-mining/blob/main/Teste_Parte_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df_1 = pd.read_csv('/content/1623535615-3006-IAJ9206.csv')

# %%
df_2 = pd.read_csv('/content/1624040490-2957-NAI1549.csv')

# %%
df_3 = pd.read_csv('/content/1624374799-3006-MYS2071.csv')

# %%
df_4 = pd.read_csv('/content/1624962426-3006-NAH4736.csv')

# %%
df_1.head()
# Out:
#           x         y         z
# 0 -1.003174 -0.097778 -0.017334
# 1 -0.993591 -0.084778 -0.009766
# 2 -0.964844 -0.048462  0.062012
# 3 -0.868591 -0.010437  0.103577
# 4 -0.885498 -0.041992  0.078003

# %%
df_2.head()
# Out:
#           x         y         z
# 0  0.029053  0.040283  0.995361
# 1  0.034851  0.041809  0.991455
# 2  0.043213  0.046143  0.988708
# 3  0.042297  0.037048  0.990601
# 4  0.050903  0.031860  0.996826

# %%
df_3.head()
# Out:
#           x         y         z
# 0 -0.913757  0.082458 -0.118225
# 1 -1.098572  0.048035 -0.115417
# 2 -1.151794  0.058899 -0.067078
# 3 -1.091187 -0.041626 -0.098022
# 4 -1.145691 -0.017517 -0.100891

# %%
df_4.head()
# Out:
#           x         y         z
# 0  0.056030 -0.132202  1.070740
# 1  0.012695 -0.122559  1.105103
# 2 -0.034119 -0.059143  1.287842
# 3 -0.099854 -0.018066  1.352234
# 4 -0.147156 -0.015686  1.086365

# %%
df_1[df_1.isna().sum(axis=1)>0]
# Out:
# Empty DataFrame
# Columns: [x, y, z]
# Index: []

# %%
df_2[df_1.isna().sum(axis=1)>0]
# Out:
# Empty DataFrame
# Columns: [x, y, z]
# Index: []

# %%
df_3[df_1.isna().sum(axis=1)>0]
# Out:
# Empty DataFrame
# Columns: [x, y, z]
# Index: []

# %%
df_4[df_1.isna().sum(axis=1)>0]
# Out:
# Empty DataFrame
# Columns: [x, y, z]
# Index: []

# %%
dicio = {'x':'start','y':'interval','z':'sensor_id'}

# %%
df_1.rename(columns=dicio, inplace=True)

# %%
df_1
# Out:
#          start  interval  sensor_id
# 0    -1.003174 -0.097778  -0.017334
# 1    -0.993591 -0.084778  -0.009766
# 2    -0.964844 -0.048462   0.062012
# 3    -0.868591 -0.010437   0.103577
# 4    -0.885498 -0.041992   0.078003
# ...        ...       ...        ...
# 4975 -1.015808  0.047424   0.120422
# 4976 -1.054077 -0.048462  -0.051331
# 4977 -1.090515 -0.046814  -0.054749
# 4978 -1.070557 -0.042114  -0.030212
# 4979 -1.016113 -0.079590   0.018066
#
# [4980 rows x 3 columns]

# %%
df_2.rename(columns=dicio, inplace=True)

# %%
df_2
# Out:
#          start  interval  sensor_id
# 0     0.029053  0.040283   0.995361
# 1     0.034851  0.041809   0.991455
# 2     0.043213  0.046143   0.988708
# 3     0.042297  0.037048   0.990601
# 4     0.050903  0.031860   0.996826
# ...        ...       ...        ...
# 4975  0.027710 -0.129272   0.993530
# 4976  0.028137 -0.121277   0.993469
# 4977  0.023621 -0.123108   0.988708
# 4978  0.019714 -0.119324   0.985535
# 4979  0.021423 -0.106750   0.993591
#
# [4980 rows x 3 columns]

# %%
df_3.rename(columns=dicio, inplace=True)

# %%
df_3
# Out:
#          start  interval  sensor_id
# 0    -0.913757  0.082458  -0.118225
# 1    -1.098572  0.048035  -0.115417
# 2    -1.151794  0.058899  -0.067078
# 3    -1.091187 -0.041626  -0.098022
# 4    -1.145691 -0.017517  -0.100891
# ...        ...       ...        ...
# 4975 -1.025757  0.023438   0.065430
# 4976 -1.008545  0.030273  -0.014282
# 4977 -1.039795  0.003662   0.124329
# 4978 -1.066589  0.002869   0.129089
# 4979 -0.968994  0.025940   0.022156
#
# [4980 rows x 3 columns]

# %%
df_4.rename(columns=dicio, inplace=True)

# %%
df_4
# Out:
#          start  interval  sensor_id
# 0     0.056030 -0.132202   1.070740
# 1     0.012695 -0.122559   1.105103
# 2    -0.034119 -0.059143   1.287842
# 3    -0.099854 -0.018066   1.352234
# 4    -0.147156 -0.015686   1.086365
# ...        ...       ...        ...
# 4975  0.096008 -0.032776   1.068115
# 4976  0.075439  0.002808   1.206482
# 4977 -0.041138  0.114014   0.938843
# 4978 -0.066406  0.238770   1.069580
# 4979 -0.081787  0.231689   1.063782
#
# [4980 rows x 3 columns]

# %%
df_1.plot()

# %%
sns.heatmap(df_1.corr(), cmap='viridis')

# %%
plt.figure(figsize=(12, 8))
df_1['start'].plot.hist(bins=20)

# %%
plt.figure(figsize=(12, 8))
df_1['interval'].plot.hist(bins=20)

# %%
plt.figure(figsize=(12, 8))
df_1['sensor_id'].plot.hist(bins=20)

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='start', y='interval', hue='sensor_id',data=df_1)

# %%
plt.figure(figsize=(12, 8))
sns.kdeplot(x='start',y='interval', data=df_1)

# %%
plt.figure(figsize=(12, 8))
sns.distplot(x=df_1['start'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
